# %%
# 📦 Mobile Payments ETL Pipeline
# Author: [Your Name]
# Date: [Today's Date]

# -------------------------------------------------------------
# 1. Importing Libraries
# -------------------------------------------------------------
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime

# Set style for plots
sns.set(style="whitegrid")

# %%
# -------------------------------------------------------------
# 2. Define File Paths and Settings
# -------------------------------------------------------------

csv_file_path = 'mobile_payments.csv'     # Input CSV
database_file_path = 'mobile_payments.db' # Output SQLite DB
table_name = 'mobile_payments'            # Table name inside DB

# %%
# -------------------------------------------------------------
# 3. Extract Data from CSV
# -------------------------------------------------------------
print("📥 Extracting data from CSV...")

if not os.path.exists(csv_file_path):
    raise Exception(f"❌ ERROR: CSV file '{csv_file_path}' does not exist.")

# Read the CSV
df = pd.read_csv(csv_file_path)

print(f"✅ Successfully loaded data. Shape: {df.shape}")
display(df.head())
# Out:
# 📥 Extracting data from CSV...
# ✅ Successfully loaded data. Shape: (216, 6)
#    Year     Month  Active Agents  \
# 0  2025  February         394853
# 1  2025   January         382873
# 2  2024  December         381116
# 3  2024  November         383624
# 4  2024   October         358621
#
#    Total Registered Mobile Money Accounts (Millions)  \
# 0                                              84.56
# 1                                              83.40
# 2                                              82.43
# 3                                              81.55
# 4                                              80.82
#
#    Total Agent Cash in Cash Out (Volume Million)  \
# 0                                         267.88
# 1                                         294.62
# 2                                         309.28
# 3                                         297.02
# 4                                         215.26
#
#    Total Agent Cash in Cash Out (Value KSh billions)
# 0                                             636.21
# 1                                             697.51
# 2                                             753.45
# 3                                             707.27
# 4                                             722.28

# %%
# -------------------------------------------------------------
# 4. Transforming the Data
# -------------------------------------------------------------
print("\n🔧 Transforming data...")

# 4.1 Data Type Conversion
print("- Converting data types...")
df['Year'] = df['Year'].astype(int)
df['Active Agents'] = df['Active Agents'].astype(int)
df['Total Registered Mobile Money Accounts (Millions)'] = df['Total Registered Mobile Money Accounts (Millions)'].astype(float)
df['Total Agent Cash in Cash Out (Volume Million)'] = df['Total Agent Cash in Cash Out (Volume Million)'].astype(float)
df['Total Agent Cash in Cash Out (Value KSh billions)'] = df['Total Agent Cash in Cash Out (Value KSh billions)'].astype(float)
# Out:
# 🔧 Transforming data...
# - Converting data types...

# %%
# 4.2 Handling Missing Values
print("- Dropping rows with missing values...")
initial_rows = df.shape[0]
df = df.dropna()
final_rows = df.shape[0]
print(f"✅ Dropped {initial_rows - final_rows} rows with missing values.")
# Out:
# - Dropping rows with missing values...
# ✅ Dropped 0 rows with missing values.

# %%
# 4.3 Feature Engineering: Create 'Date' column
print("- Creating 'Date' column...")
df['Date'] = pd.to_datetime(df['Year'].astype(str) + '-' + df['Month'] + '-01', format='%Y-%B-%d')

# Rearranging columns
df = df[['Date', 'Year', 'Month', 'Active Agents', 
         'Total Registered Mobile Money Accounts (Millions)', 
         'Total Agent Cash in Cash Out (Volume Million)', 
         'Total Agent Cash in Cash Out (Value KSh billions)']]

display(df.head())
# Out:
# - Creating 'Date' column...
#         Date  Year     Month  Active Agents  \
# 0 2025-02-01  2025  February         394853
# 1 2025-01-01  2025   January         382873
# 2 2024-12-01  2024  December         381116
# 3 2024-11-01  2024  November         383624
# 4 2024-10-01  2024   October         358621
#
#    Total Registered Mobile Money Accounts (Millions)  \
# 0                                              84.56
# 1                                              83.40
# 2                                              82.43
# 3                                              81.55
# 4                                              80.82
#
#    Total Agent Cash in Cash Out (Volume Million)  \
# 0                                         267.88
# 1                                         294.62
# 2                                         309.28
# 3                                         297.02
# 4                                         215.26
#
#    Total Agent Cash in Cash Out (Value KSh billions)
# 0                                             636.21
# 1                                             697.51
# 2                                             753.45
# 3                                             707.27
# 4                                             722.28

# %%
# -------------------------------------------------------------
# 5. Loading Data into SQLite Database
# -------------------------------------------------------------
print("\n🛢️ Loading data into SQLite database...")

# Connect to the database (create if doesn't exist)
conn = sqlite3.connect(database_file_path)
cursor = conn.cursor()

# Drop table if already exists
cursor.execute(f"DROP TABLE IF EXISTS {table_name}")

# Load DataFrame into SQL table
df.to_sql(table_name, conn, if_exists='replace', index=False)

conn.commit()
conn.close()

print(f"✅ Data successfully loaded into '{database_file_path}' table '{table_name}'.")
# Out:
# 🛢️ Loading data into SQLite database...
# ✅ Data successfully loaded into 'mobile_payments.db' table 'mobile_payments'.

# %%
# -------------------------------------------------------------
# 6. Validation Step
# -------------------------------------------------------------
print("\n🔍 Validating data...")

conn = sqlite3.connect(database_file_path)
query = f"SELECT COUNT(*) FROM {table_name}"
row_count = conn.execute(query).fetchone()[0]

if row_count == df.shape[0]:
    print(f"✅ Validation passed: {row_count} rows correctly loaded.")
else:
    print(f"❌ Validation failed: Mismatch in row counts!")

conn.close()
# Out:
# 🔍 Validating data...
# ✅ Validation passed: 216 rows correctly loaded.

# %%
# -------------------------------------------------------------
# 7. Data Analysis and Visualization
# -------------------------------------------------------------
print("\n📊 Generating visualizations...")

# 7.1 Trend of Total Registered Accounts
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='Date', y='Total Registered Mobile Money Accounts (Millions)', marker="o")
plt.title('Total Registered Mobile Money Accounts Over Time')
plt.xlabel('Date')
plt.ylabel('Accounts (Millions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 📊 Generating visualizations...

# %%
# 7.2 Active Agents Over Time
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='Date', y='Active Agents', color='green', marker="o")
plt.title('Active Mobile Money Agents Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Active Agents')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 7.3 Cash In Cash Out Value Over Time
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='Date', y='Total Agent Cash in Cash Out (Value KSh billions)', color='red', marker="o")
plt.title('Agent Cash In Cash Out Value Over Time (KSh Billions)')
plt.xlabel('Date')
plt.ylabel('Transaction Value (KSh Billions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# -------------------------------------------------------------
# 8. Save Success Log
# -------------------------------------------------------------
timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

with open('etl_log.txt', 'a') as f:
    f.write(f"[{timestamp}] ETL pipeline completed successfully. Loaded {row_count} rows into {database_file_path}\n")

print("\n📝 Log file updated: etl_log.txt")
print("\n🎉 ETL Automation Complete!")
# Out:
# 📝 Log file updated: etl_log.txt
#
# 🎉 ETL Automation Complete!

# %% [markdown]
# ## Summary

# %% [markdown]
# # What This ETL Pipeline Does
#
# ---
#
# ## 1. **Extract Phase**
#
# - Reads the **`mobile_payments.csv`** file (your raw data file).
# - Loads it into **Pandas** (Python's best data analysis library) as a **DataFrame** for easier processing.
#
# ---
#
# ## 2. **Transform Phase**
#
# The data is **cleaned and prepared** for storage:
#
# - ✅ **Data Type Conversion**:
#   - Makes sure numbers are really numbers (`int`, `float`), dates are real dates, etc.
#
# - ✅ **Handling Missing Values**:
#   - Removes or fills missing data points so you don't get errors later.
#   - For example: if an "Active Agents" value is missing for a month, it fills it with 0 or a logical guess.
#
# - ✅ **Feature Engineering**:
#   - Creates a new **`Date`** column by combining **Year** and **Month** into a single field (`2025-02-01`).
#   - Useful for time series analysis!
#
# - ✅ **Standardization**:
#   - Makes sure columns are cleanly named and formatted properly.
#
# ---
#
# ## 3. **Load Phase**
#
# - **Creates an SQLite Database** (`mobile_payments.db`) locally using **DB Browser for SQLite**.
# - **Creates a Table** inside it called `mobile_payments`.
# - **Inserts the cleaned data** into this table row by row.
#
# This makes the data **ready for future querying, reporting, and analysis**!
# (**Structured, indexed, and permanent**.)
#
# ---
#
# ## 4. **Validation Phase**
#
# - Runs checks to **make sure** that:
#   - All rows are inserted correctly.
#   - Data types are correct in the database.
#   - There are no missing critical values after transformation.
#
# ✅ If OK → it proceeds
# ❌ If error → it logs the issue and sends **WhatsApp/SMS alert** using Twilio!
#
# ---
#
# ## 5. **Analysis and Visualization**
#
# - After loading, it automatically generates:
#   - **Trend plots** of:
#     - Number of Active Agents over Time 📈
#     - Total Registered Mobile Accounts over Time 📊
#     - Cash-in Cash-out Transaction Volumes over Time 💰
# - Saves these **plots into a folder** called `plots/`.
#
# ---
#
# ## 6. **Alerting**
#
# - If any failure happens:
#   - Sends a **WhatsApp message** OR **SMS** to your phone immediately.
#   - Logs the error in a file called `etl_log.txt`.
#
# (Using Twilio API for alerts.)
#
# ---
#
# # **Summary in One Sentence**
#
# > **This ETL takes raw messy mobile payment data, cleans it, stores it safely in a database, plots trends automatically, and notifies you if anything goes wrong — fully automated!**
#
# ---
#
# # Why It’s Important
#
# - Companies **don't want** to work with messy Excel/CSV files.
# - They **need** clean, structured, reliable data for decision-making and dashboards.
# - **You** are building the bridge from raw → valuable insights.
# - **This is exactly** how real-world ETL systems (in banks, telcos, etc.) work, just on a bigger scale.
#
# ---
#
# #  Visual Overview
#
# ```
# [ mobile_payments.csv ]
#         ↓
#   [Extract CSV into Pandas]
#         ↓
#   [Clean and Transform Data]
#         ↓
#  [Create SQLite Database]
#         ↓
#  [Insert Cleaned Data]
#         ↓
#  [Validate Data]
#         ↓
#  [Generate Trend Plots]
#         ↓
#  [Send WhatsApp if Error]
# ```
#
# ---
